# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Load the CSVs
df = pd.read_csv ('02_complete-data-pop.csv', index_col='date', parse_dates=True)

print(df.head())
print(df.dtypes)
# Out:
#             Unnamed: 0  Unnamed: 0.1  Confirmed         country  Deaths  \
# date
# 2020-01-22           0             0        1.0  Mainland China     NaN
# 2020-01-22           1             1       14.0  Mainland China     NaN
# 2020-01-22           2             2        6.0  Mainland China     NaN
# 2020-01-22           3             3        1.0  Mainland China     NaN
# 2020-01-22           4             4        NaN  Mainland China     NaN
#
#                 Last Update  Latitude  Longitude   province  Recovered  ...  \
# date                                                                    ...
# 2020-01-22  1/22/2020 17:00       NaN        NaN      Anhui        NaN  ...
# 2020-01-22  1/22/2020 17:00       NaN        NaN    Beijing        NaN  ...
# 2020-01-22  1/22/2020 17:00       NaN        NaN  Chongqing        NaN  ...
# 2020-01-22  1/22/2020 17:00       NaN        NaN     Fujian        NaN  ...
# 2020-01-22  1/22/2020 17:00       NaN        NaN      Gansu        NaN  ...
#
#            confirmed_per_Thousand  mortality_percent  % Mortality  active  \
# date
# 2020-01-22           6.947707e-07                NaN          NaN     1.0
# 2020-01-22           9.726790e-06                NaN          NaN    14.0
# 2020-01-22           4.168624e-06                NaN          NaN     6.0
# 2020-01-22           6.947707e-07                NaN          NaN     1.0
# 2020-01-22                    NaN                NaN          NaN     NaN
#
#             active_percent      % Active  active_per_Thousand  \
# date
# 2020-01-22    6.947707e-10  6.947707e-08         6.947707e-07
# 2020-01-22    9.726790e-09  9.726790e-07         9.726790e-06
# 2020-01-22    4.168624e-09  4.168624e-07         4.168624e-06
# 2020-01-22    6.947707e-10  6.947707e-08         6.947707e-07
# 2020-01-22             NaN           NaN                  NaN
#
#             recovered_per_Thousand  recovered_percent  % Recovered
# date
# 2020-01-22                     NaN                NaN          NaN
# 2020-01-22                     NaN                NaN          NaN
# 2020-01-22                     NaN                NaN          NaN
# 2020-01-22                     NaN                NaN          NaN
# 2020-01-22                     NaN                NaN          NaN
#
# [5 rows x 24 columns]
# Unnamed: 0                  int64
# Unnamed: 0.1                int64
# Confirmed                 float64
# country                    object
# Deaths                    float64
# Last Update                object
# Latitude                  float64
# Longitude                 float64
# province                   object
# Recovered                 float64
# name                       object
# pop2020                   float64
# confirmed_percent         float64
# % Confirmed               float64
# confirmed_per_Thousand    float64
# mortality_percent         float64
# % Mortality               float64
# active                    float64
# active_percent            float64
# % Active                  float64
# active_per_Thousand       float64
# recovered_per_Thousand    float64
# recovered_percent         float64
# % Recovered               float64
# dtype: object

# %%
#The same as plot
df.groupby(['date'])["Confirmed",'Deaths','Recovered'].sum().plot()

# %%
df_germany=df[df['country'] == 'Germany']
#The same as plot
df_germany.groupby(['date'])["Confirmed",'Deaths','Recovered'].sum().plot()

# %%
df_gb=df[df['country'] == 'United Kingdom']
#The same as plot
df_gb.groupby(['date'])["Confirmed",'Deaths','Recovered'].sum().plot()

# %%
df_it=df[df['country'] == 'Italy']
#The same as plot
df_it.groupby(['date'])["Confirmed",'Deaths','Recovered'].sum().plot()

# %%
df_germany=df[df['country'] == 'Germany']
#The same as plot
df_germany.groupby(['date'])["confirmed_percent",'mortality_percent','active_percent'].sum().plot()

# %%
#Filter
df_germany=df[df['country'] == 'Germany']

#print(df_germany)

dfnew=df_germany.groupby(['date'])["% Confirmed","% Active","% Recovered"].sum()

#print(dfnew)

# Add title and axis names

dfnew.plot()
plt.title('COVID 2019 - Germany')
plt.ylabel('% of Population')
plt.xlabel('Date')
plt.xticks(rotation=0)
# Out:
# (array([18289, 18293, 18322, 18334], dtype=int64),
#  <a list of 4 Text xticklabel objects>)

# %%
#Filter
df_italy=df[df['country'] == 'Italy']

#print(df_germany)

dfnew=df_italy.groupby(['date'])["% Confirmed","% Active","% Recovered"].sum()

#print(dfnew)

# Add title and axis names

dfnew.plot()
plt.title('COVID 2019 - Italy')
plt.ylabel('% of Population')
plt.xlabel('Date')
plt.xticks(rotation=0)
# Out:
# (array([18292, 18293, 18322, 18334], dtype=int64),
#  <a list of 4 Text xticklabel objects>)

# %%
#Filter
df_germany=df[df['country'] == 'Germany']

#print(df_germany)

dfnew=df_germany.groupby(['date'])["% Mortality"].sum()

#print(dfnew)

# Add title and axis names

dfnew.plot()
plt.title('COVID 2019 - Germany')
plt.ylabel('% Mortality')
plt.xlabel('Date')
plt.xticks(rotation=0)
# Out:
# (array([18289, 18293, 18322, 18334], dtype=int64),
#  <a list of 4 Text xticklabel objects>)

# %%
#Filer
df_china=df[df['country'] == 'Mainland China']

#print(df_germany)

dfnew=df_china.groupby(['date'])["confirmed_per_Thousand","active_per_Thousand"].sum()
# Add title and axis names

dfnew.plot()
plt.title('COVID 2019 - China')
plt.ylabel('Confirmed per 1000 People')
plt.xlabel('Date')
plt.xticks(rotation=90)
# Out:
# (array([18283, 18293, 18322, 18333], dtype=int64),
#  <a list of 4 Text xticklabel objects>)
