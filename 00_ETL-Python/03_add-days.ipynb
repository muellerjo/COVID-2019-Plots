# %%
#!/usr/bin/env python3
import io
import pandas as pd

#--------------------------------------------------------------------------------------------
# ETL-Process
#--------------------------------------------------------------------------------------------

DATA = pd.read_csv ('../01_ETLOutput-CSV/02-data-grouped-population.csv', parse_dates=True)
#transform the date from csv from object to datetime
DATA['date'] = DATA['date'].astype('datetime64')

#--------------------------------------------------------------------------------------------
# DAYS SINCE PAT 1
#--------------------------------------------------------------------------------------------

#Method for adding days to the datasets
def add_days(dataframe):
    print("add_days started")
    dates = dataframe.index.get_level_values(1)
    return dataframe.assign(days1=dates - dates[0] + pd.Timedelta(days=1))

#Sex indexes and sort by country and date
df = DATA.set_index(["country", "date"]).sort_index()

#Nummerize since Day 1
df_pat1 = df[df["Confirmed"] > 0].groupby(level=0).apply(add_days)
#remove the word 'day' from days
df_pat1['days1'] = df_pat1['days1'].dt.days
#Write to csv
df_pat1.to_csv('../01_ETLOutput-CSV/03_complete-data-pop-days1.csv')

#--------------------------------------------------------------------------------------------
# DAYS SINCE PAT 100
#--------------------------------------------------------------------------------------------

def add_days100(dataframe):
    print("add_days100 started")
    dates = dataframe.index.get_level_values(1)
    return dataframe.assign(days100=dates - dates[0] + pd.Timedelta(days=1))

#Nummerize since Day 1
df_pat100 = df[df["Confirmed"] >= 100].groupby(level=0).apply(add_days100)
#remove the word 'day' from days
df_pat100['days100'] = df_pat100['days100'].dt.days
#Write to csv
df_pat100.to_csv('../01_ETLOutput-CSV/03_complete-data-pop-days100.csv')


print(df_pat1.head())
print(df_pat100.head())
# Out:
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
# add_days100 started
#                         Unnamed: 0  Confirmed  Deaths  Recovered         name  \
# country     date
#  Azerbaijan 2020-02-28        1030        1.0     0.0        0.0          NaN
# Afghanistan 2020-02-24         848        1.0     0.0        0.0  Afghanistan
#             2020-02-25         886        1.0     0.0        0.0  Afghanistan
#             2020-02-26         928        1.0     0.0        0.0  Afghanistan
#             2020-02-27         977        1.0     0.0        0.0  Afghanistan
#
#                           pop2020  PercentOfPopulationConfirmedDecimal  \
# country     date
#  Azerbaijan 2020-02-28        NaN                                  NaN
# Afghanistan 2020-02-24  38928.346                         2.568822e-08
#             2020-02-25  38928.346                         2.568822e-08
#             2020-02-26  38928.346                         2.568822e-08
#             2020-02-27  38928.346                         2.568822e-08
#
#                         PercentOfPopulationConfirmed  MortalityDecimal  \
# country     date
#  Azerbaijan 2020-02-28                           NaN               0.0
# Afghanistan 2020-02-24                      0.000003               0.0
#             2020-02-25                      0.000003               0.0
#             2020-02-26                      0.000003               0.0
#             2020-02-27                      0.000003               0.0
#
#                         MortalityPercent  active  \
# country     date
#  Azerbaijan 2020-02-28               0.0     1.0
# Afghanistan 2020-02-24               0.0     1.0
#             2020-02-25               0.0     1.0
#             2020-02-26               0.0     1.0
#             2020-02-27               0.0     1.0
#
#                         PercentOfPopulationActiveDecimal  \
# country     date
#  Azerbaijan 2020-02-28                               NaN
# Afghanistan 2020-02-24                      2.568822e-08
#             2020-02-25                      2.568822e-08
#             2020-02-26                      2.568822e-08
#             2020-02-27                      2.568822e-08
#
#                         PercentOfPopulationActive  \
# country     date
#  Azerbaijan 2020-02-28                        NaN
# Afghanistan 2020-02-24                   0.000003
#             2020-02-25                   0.000003
#             2020-02-26                   0.000003
#             2020-02-27                   0.000003
#
#                         PercentOfPopulationRecoveredDecimal  \
# country     date
#  Azerbaijan 2020-02-28                                  NaN
# Afghanistan 2020-02-24                                  0.0
#             2020-02-25                                  0.0
#             2020-02-26                                  0.0
#             2020-02-27                                  0.0
#
#                         PercentOfPopulationRecovered  days1
# country     date
#  Azerbaijan 2020-02-28                           NaN      1
# Afghanistan 2020-02-24                           0.0      1
#             2020-02-25                           0.0      2
#             2020-02-26                           0.0      3
#             2020-02-27                           0.0      4
#                       Unnamed: 0  Confirmed  Deaths  Recovered       name  \
# country   date
# Algeria   2020-03-21        3558      139.0    15.0       32.0    Algeria
# Argentina 2020-03-20        3388      128.0     3.0        3.0  Argentina
#           2020-03-21        3562      158.0     4.0        3.0  Argentina
# Armenia   2020-03-19        3220      115.0     0.0        1.0    Armenia
#           2020-03-20        3389      136.0     0.0        1.0    Armenia
#
#                         pop2020  PercentOfPopulationConfirmedDecimal  \
# country   date
# Algeria   2020-03-21  43851.044                             0.000003
# Argentina 2020-03-20  45195.774                             0.000003
#           2020-03-21  45195.774                             0.000003
# Armenia   2020-03-19   2963.243                             0.000039
#           2020-03-20   2963.243                             0.000046
#
#                       PercentOfPopulationConfirmed  MortalityDecimal  \
# country   date
# Algeria   2020-03-21                      0.000317          0.107914
# Argentina 2020-03-20                      0.000283          0.023438
#           2020-03-21                      0.000350          0.025316
# Armenia   2020-03-19                      0.003881          0.000000
#           2020-03-20                      0.004590          0.000000
#
#                       MortalityPercent  active  \
# country   date
# Algeria   2020-03-21         10.791367   107.0
# Argentina 2020-03-20          2.343750   125.0
#           2020-03-21          2.531646   155.0
# Armenia   2020-03-19          0.000000   114.0
#           2020-03-20          0.000000   135.0
#
#                       PercentOfPopulationActiveDecimal  \
# country   date
# Algeria   2020-03-21                          0.000002
# Argentina 2020-03-20                          0.000003
#           2020-03-21                          0.000003
# Armenia   2020-03-19                          0.000038
#           2020-03-20                          0.000046
#
#                       PercentOfPopulationActive  \
# country   date
# Algeria   2020-03-21                   0.000317
# Argentina 2020-03-20                   0.000283
#           2020-03-21                   0.000350
# Armenia   2020-03-19                   0.003881
#           2020-03-20                   0.004590
#
#                       PercentOfPopulationRecoveredDecimal  \
# country   date
# Algeria   2020-03-21                         7.297432e-07
# Argentina 2020-03-20                         6.637789e-08
#           2020-03-21                         6.637789e-08
# Armenia   2020-03-19                         3.374681e-07
#           2020-03-20                         3.374681e-07
#
#                       PercentOfPopulationRecovered  days100
# country   date
# Algeria   2020-03-21                      0.000073        1
# Argentina 2020-03-20                      0.000007        1
#           2020-03-21                      0.000007        2
# Armenia   2020-03-19                      0.000034        1
#           2020-03-20                      0.000034        2
